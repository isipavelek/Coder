# %% [markdown]
# ## Desafio2
#
# Alumno: Israel Pavelek
#
# Consigna:
# * 1_Generar un array aleatorio de 100 elementos. Calcular la mediana correspondiente.
# * 2_Recordar los ejercicios con funciones para el cálculo de factorial y suma de serie de la Clase 02. Repetir ambos ejercicios, pero ahora utilizar las nuevas operaciones aprendidas con los ndarrays.
# * 3_Se provee un archivo con los resultados de la Encuesta de Sueldos de Openqube de Febrero 2020. Calcular y comparar media y mediana de los sueldos netos.

# %% [markdown]
# ## Ejercicio 1

# %%
import numpy as np
array=np.random.rand(100).round(3)  #redondeo a 3 decimales para simplicidad visual en este caso
median=np.median(array)
print(array)
print("La mediana vale: " +str(median))
# Out:
# [0.52  0.634 0.772 0.583 0.785 0.144 0.891 0.114 0.275 0.002 0.067 0.519
#  0.763 0.175 0.506 0.752 0.162 0.558 0.765 0.778 0.951 0.179 0.366 0.987
#  0.64  0.389 0.261 0.675 0.559 0.493 0.386 0.362 0.426 0.297 0.631 0.409
#  0.954 0.904 0.259 0.063 0.992 0.148 0.76  0.122 0.221 0.275 0.413 0.462
#  0.509 0.021 0.959 0.229 0.822 0.623 0.461 0.007 0.596 0.922 0.97  0.713
#  0.476 0.548 0.67  0.719 0.353 0.057 0.68  0.634 0.384 0.8   0.264 0.922
#  0.772 0.617 0.614 0.682 0.075 0.408 0.414 0.068 0.879 0.571 0.301 0.088
#  0.6   0.716 0.698 0.774 0.197 0.282 0.919 0.725 0.345 0.856 0.057 0.772
#  0.968 0.344 0.605 0.147]
# La mediana vale: 0.534

# %% [markdown]
# ## Ejercicio 2

# %%
def factorial(numero):
   return np.prod(range(1,numero+1))

#CALCULAMOS EL FACTORIAL DE 3
fact3=factorial(3)

#VISUALIZAMOS RESULTADO.
print(fact3)
# Out:
# 6

# %%
def sumatoria(comienzo,final):
    
    if ((final<comienzo) or (comienzo==final)):
        resultado=-1
        print("Error debe ingresar un valor final mayor que el de comienzo")
    else:
        resultado=np.sum(range(comienzo,final+1))

    return resultado


#CALCULAMOS LA SUMATORIA DE 1 a 10
res=sumatoria(1,10)

#VISUALIZAMOS RESULTADO.
print(res)
# Out:
# 55

# %% [markdown]
# ## Ejercicio 3

# %%
import pandas as pd

df=pd.read_csv('Salarios Openqube - 2020.02.csv')  
df.head()
# Out:
#            Timestamp Me identifico  Tengo Estoy trabajando en  \
# 0   7/6/2020 9:56:02         Mujer     26           Argentina
# 1   7/6/2020 9:57:09        Hombre     29           Argentina
# 2   7/6/2020 9:58:09         Mujer     22           Argentina
# 3   7/6/2020 9:59:52        Hombre     39           Argentina
# 4  7/6/2020 10:01:27        Hombre     32           Argentina
#
#             Dónde estás trabajando Bolivia Chile Colombia Cuba Costa Rica  \
# 0  Ciudad Autónoma de Buenos Aires     NaN   NaN      NaN  NaN        NaN
# 1                       Corrientes     NaN   NaN      NaN  NaN        NaN
# 2  Ciudad Autónoma de Buenos Aires     NaN   NaN      NaN  NaN        NaN
# 3                       Corrientes     NaN   NaN      NaN  NaN        NaN
# 4  Ciudad Autónoma de Buenos Aires     NaN   NaN      NaN  NaN        NaN
#
#    ... ¿Con cuántas personas estás conviviendo?  \
# 0  ...                                        0
# ...

# %%
mediana=np.nanmedian(df['Salario mensual BRUTO (en tu moneda local)'])
media=np.nanmean(df['Salario mensual BRUTO (en tu moneda local)'])
print("La mediana del salariao mensual Bruto es: "+ str(mediana))
print("La media del salariao mensual Bruto es: "+ str(media))
# Out:
# La mediana del salariao mensual Bruto es: 95000.0
# La media del salariao mensual Bruto es: 2992143846.202422
